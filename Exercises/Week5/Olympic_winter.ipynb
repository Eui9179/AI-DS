# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
url = "https://ko.wikipedia.org/wiki/%EC%98%AC%EB%A6%BC%ED%94%BD_%EB%A9%94%EB%8B%AC_%EC%A7%91%EA%B3%84"

df = pd.read_html(url, header=0, index_col=0)
a = df[0].iloc[:,5:10]
a.columns = ['동계 참가 횟수', '금', '은', '동', '계']
a = a.sort_values(['동계 참가 횟수', '금'], ascending=False)
a_top_15 = a[1:16]
a_top_15
# Out:
#                               동계 참가 횟수    금    은    동    계
# 국가 (IOC 코드)
# 노르웨이 (NOR) [Q]                      23  132  125  111  368
# 미국 (USA) [P] [Q] [R] [Z] [F]        23  105  112   88  305
# 캐나다 (CAN)                           23   73   64   62  199
# 오스트리아 (AUT)                         23   64   81   87  232
# 스웨덴 (SWE) [Z]                       23   57   46   55  158
# 스위스 (SUI)                           23   56   45   52  153
# 핀란드 (FIN)                           23   43   63   61  167
# 이탈리아 (ITA) [M] [S]                  23   40   36   48  124
# 프랑스 (FRA) [O] [P] [Z]               23   36   35   53  124
# 영국 (GBR) [GBR] [Z]                  23   11    4   17   32
# 폴란드 (POL)                           23    7    7    8   22
# 헝가리 (HUN)                           23    1    2    4    7
# 네덜란드 (NED) [Z]                      21   45   44   41  130
# 일본 (JPN)                            21   14   22   22   58
# 벨기에 (BEL)                           21    1    2    3    6

# %%
plt.rc('font', family='NanumGothic')
plt.rcParams['axes.unicode_minus'] = False
plt.style.use('ggplot')

# %%
a_top_15.plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='국가 (IOC 코드)'>
