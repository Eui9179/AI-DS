# %%
from glob import glob
import pandas as pd

# %%
station_files = glob('지역*.xls')
station_files
# Out:
# ['지역_위치별(주유소) (1).xls',
#  '지역_위치별(주유소) (10).xls',
#  '지역_위치별(주유소) (2).xls',
#  '지역_위치별(주유소) (3).xls',
#  '지역_위치별(주유소) (4).xls',
#  '지역_위치별(주유소) (5).xls',
#  '지역_위치별(주유소) (6).xls',
#  '지역_위치별(주유소) (7).xls',
#  '지역_위치별(주유소) (8).xls',
#  '지역_위치별(주유소) (9).xls']

# %%
tmp_list = []

for filename in station_files:
    tmp = pd.read_excel(filename, header=2)
    tmp_list.append(tmp)
    
tmp_list[0]
# Out:
#        지역              상호                     주소      상표          전화번호 셀프여부  \
# 0   인천광역시         하은상사주유소     인천 강화군 길상면 해안동로 75   GS칼텍스  032-937-9914    Y
# 1   인천광역시           두운주유소    인천 강화군 불은면 강화동로 508   SK에너지  032-933-0366    N
# 2   인천광역시           아름주유소     인천 강화군 선원면 중앙로 150   GS칼텍스  032-933-5145    Y
# 3   인천광역시         강화농협주유소      인천 강화군 강화읍 중앙로 70  NH-OIL  032-933-0556    Y
# 4   인천광역시           금광주유소      인천 강화군 길상면 까치골길 1   S-OIL  032-937-5104    N
# 5   인천광역시           온수주유소     인천 강화군 길상면 초지로 568   SK에너지  032-937-9470    Y
# 6   인천광역시         선원부광주유소    인천 강화군 선원면 강화동로 899   SK에너지  032-933-8182    N
# 7   인천광역시           양도주유소    인천 강화군 양도면 강화남로 725   SK에너지  032-937-0119    N
# 8   인천광역시           해명주유소    인천 강화군 삼산면 삼산남로 536   SK에너지  032-932-5225    N
# 9   인천광역시  KH에너지㈜직영 삼성주유소     인천 강화군 불은면 중앙로 638   SK에너지  032-937-6208    N
# 10  인천광역시           하점주유소    인천 강화군 하점면 강화대로 909  현대오일뱅크  032-934-5189    N
# 11  인천광역시          서문안주유소     인천 강화군 불은면 중앙로 665  현대오일뱅크  032-937-3006    N
# 12  인천광역시          태평양주유소    인천 강화군 하점면 강화서로 557   SK에너지  032-932-4109    N
# 13  인천광역시       강화남부농협주유소     인천 강화군 길상면 길상로 302   SK에너지  032-937-4185    N
# 14  인천광역시           삼산주유소    인천 강화군 삼산면 삼산북로 462   SK에너지  032-932-3027    N
# 15  인천광역시           대동주유소    인천 강화군 불은면 강화동로 176   SK에너지  032-937-9100    N
# 16  인천광역시           길상주유소     인천 강화군 길상면 길상로 348   SK에너지  032-937-2323    N
# 17  인천광역시           경기주유소     인천 강화군 선원면 중앙로 233   SK에너지  032-933-5060    Y
# 18  인천광역시        (주)유성주유소   인천 강화군 하점면 강화대로 1114   SK에너지  032-933-5190    N
# 19  인천광역시        서강화농협주유소    인천 강화군 교동면 교동동로 480  NH-OIL  032-933-8328    N
# 20  인천광역시          가나안주유소   인천 강화군 화도면 해안남로 2351   GS칼텍스  032-937-4510    Y
# 21  인천광역시           화도주유소     인천 강화군 화도면 가능포로 37  현대오일뱅크  032-937-6829    N
# 22  인천광역시           세광주유소     인천 강화군 선원면 중앙로 205   S-OIL  032-934-1235    N
# 23  인천광역시           한국주유소     인천 강화군 선원면 중앙로 445    자가상표  032-933-8700    N
# 24  인천광역시           교동주유소  인천 강화군 교동면 대룡안길54번길 5   GS칼텍스  032-932-5039    N
# 25  인천광역시        백마외포리주유소    인천 강화군 내가면 중앙로 1301   S-OIL  032-933-8155    N
# 26  인천광역시           양갑주유소    인천 강화군 교동면 교동서로 274   SK에너지  032-933-8126    N
#
#    고급휘발유   휘발유    경유  실내등유
# 0      -  1585  1829  1460
# 1      -  1599  1840  1470
# 2      -  1629  1879  1549
# 3      -  1630  1865  1500
# 4      -  1645  1855  1475
# 5      -  1650  1870  1500
# 6      -  1659  1898  1500
# 7      -  1667  1897  1515
# 8      -  1667  1897  1550
# 9      -  1668  1898  1640
# 10     -  1668  1898  1550
# 11     -  1668  1898  1550
# 12     -  1669  1899  1550
# 13     -  1670  1880  1520
# 14     -  1670  1900     -
# 15     -  1670  1875  1520
# 16     -  1670  1880  1520
# 17     -  1679  1899  1500
# 18     -  1690  1920  1550
# 19     -  1695  1933  1560
# 20     -  1697  1825  1500
# 21     -  1698  1928  1550
# 22     -  1699  1899  1550
# 23     -  1719  1899  1600
# 24     -  1720  1995  1600
# 25     -  1790  1998  1690
# 26     -  1795  1990  1695

# %%
stations = pd.concat(tmp_list)
stations.shape
# Out:
# (319, 10)

# %%
stations.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 319 entries, 0 to 10
# Data columns (total 10 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   지역      319 non-null    object
#  1   상호      319 non-null    object
#  2   주소      319 non-null    object
#  3   상표      319 non-null    object
#  4   전화번호    319 non-null    object
#  5   셀프여부    319 non-null    object
#  6   고급휘발유   319 non-null    object
#  7   휘발유     319 non-null    object
#  8   경유      319 non-null    object
#  9   실내등유    319 non-null    object
# dtypes: object(10)
# memory usage: 27.4+ KB

# %%
stations_sel = stations.loc[:,['상호', '주소', '상표', '셀프여부', '휘발유']]
stations_sel.columns = ['주유소', '주소', '상표', '셀프여부', '가격']
stations_sel
# Out:
#         주유소                   주소      상표 셀프여부    가격
# 0   하은상사주유소   인천 강화군 길상면 해안동로 75   GS칼텍스    Y  1585
# 1     두운주유소  인천 강화군 불은면 강화동로 508   SK에너지    N  1599
# 2     아름주유소   인천 강화군 선원면 중앙로 150   GS칼텍스    Y  1629
# 3   강화농협주유소    인천 강화군 강화읍 중앙로 70  NH-OIL    Y  1630
# 4     금광주유소    인천 강화군 길상면 까치골길 1   S-OIL    N  1645
# ..      ...                  ...     ...  ...   ...
# 6     연평주유소   인천 옹진군 연평면 연평로 715  현대오일뱅크    N  1890
# 7     백령주유소   인천 옹진군 백령면 백령로 221   S-OIL    N  1890
# 8     대청주유소   인천 옹진군 대청면 대청로 222  현대오일뱅크    Y  1890
# 9     북포주유소   인천 옹진군 백령면 백령로 859  현대오일뱅크    N  1890
# 10    장봉주유소   인천 옹진군 북도면 장봉로 467    자가상표    N  1950
#
# [319 rows x 5 columns]

# %%
gu_list = []
for address in stations['주소']:
    address_gu = address.split()[1]
    gu_list.append(address_gu)

stations_sel['군/구'] = gu_list
stations_sel
# Out:
#         주유소                   주소      상표 셀프여부    가격  군/구
# 0   하은상사주유소   인천 강화군 길상면 해안동로 75   GS칼텍스    Y  1585  강화군
# 1     두운주유소  인천 강화군 불은면 강화동로 508   SK에너지    N  1599  강화군
# 2     아름주유소   인천 강화군 선원면 중앙로 150   GS칼텍스    Y  1629  강화군
# 3   강화농협주유소    인천 강화군 강화읍 중앙로 70  NH-OIL    Y  1630  강화군
# 4     금광주유소    인천 강화군 길상면 까치골길 1   S-OIL    N  1645  강화군
# ..      ...                  ...     ...  ...   ...  ...
# 6     연평주유소   인천 옹진군 연평면 연평로 715  현대오일뱅크    N  1890  옹진군
# 7     백령주유소   인천 옹진군 백령면 백령로 221   S-OIL    N  1890  옹진군
# 8     대청주유소   인천 옹진군 대청면 대청로 222  현대오일뱅크    Y  1890  옹진군
# 9     북포주유소   인천 옹진군 백령면 백령로 859  현대오일뱅크    N  1890  옹진군
# 10    장봉주유소   인천 옹진군 북도면 장봉로 467    자가상표    N  1950  옹진군
#
# [319 rows x 6 columns]

# %% [markdown]
# ## 군/구 목록 확인

# %%
stations_sel['군/구'].unique()
# Out:
# array(['강화군', '중구', '계양구', '남동구', '동구', '미추홀구', '남구', '부평구', '서구', '연수구',
#        '옹진군'], dtype=object)

# %% [markdown]
# ## 예외 처리하기
# - 가격이 기입되어 있지 않은 주유소 제외

# %%
stations_sel = stations_sel.query("가격 != '-'").copy()
stations_sel
# Out:
#         주유소                   주소      상표 셀프여부    가격  군/구
# 0   하은상사주유소   인천 강화군 길상면 해안동로 75   GS칼텍스    Y  1585  강화군
# 1     두운주유소  인천 강화군 불은면 강화동로 508   SK에너지    N  1599  강화군
# 2     아름주유소   인천 강화군 선원면 중앙로 150   GS칼텍스    Y  1629  강화군
# 3   강화농협주유소    인천 강화군 강화읍 중앙로 70  NH-OIL    Y  1630  강화군
# 4     금광주유소    인천 강화군 길상면 까치골길 1   S-OIL    N  1645  강화군
# ..      ...                  ...     ...  ...   ...  ...
# 6     연평주유소   인천 옹진군 연평면 연평로 715  현대오일뱅크    N  1890  옹진군
# 7     백령주유소   인천 옹진군 백령면 백령로 221   S-OIL    N  1890  옹진군
# 8     대청주유소   인천 옹진군 대청면 대청로 222  현대오일뱅크    Y  1890  옹진군
# 9     북포주유소   인천 옹진군 백령면 백령로 859  현대오일뱅크    N  1890  옹진군
# 10    장봉주유소   인천 옹진군 북도면 장봉로 467    자가상표    N  1950  옹진군
#
# [316 rows x 6 columns]

# %%
price_list = []

for price in stations_sel['가격']:
    price_new = int(price)
    price_list.append(price_new)

stations_sel['가격'] = price_list
stations_sel
# Out:
#         주유소                   주소      상표 셀프여부    가격  군/구
# 0   하은상사주유소   인천 강화군 길상면 해안동로 75   GS칼텍스    Y  1585  강화군
# 1     두운주유소  인천 강화군 불은면 강화동로 508   SK에너지    N  1599  강화군
# 2     아름주유소   인천 강화군 선원면 중앙로 150   GS칼텍스    Y  1629  강화군
# 3   강화농협주유소    인천 강화군 강화읍 중앙로 70  NH-OIL    Y  1630  강화군
# 4     금광주유소    인천 강화군 길상면 까치골길 1   S-OIL    N  1645  강화군
# ..      ...                  ...     ...  ...   ...  ...
# 6     연평주유소   인천 옹진군 연평면 연평로 715  현대오일뱅크    N  1890  옹진군
# 7     백령주유소   인천 옹진군 백령면 백령로 221   S-OIL    N  1890  옹진군
# 8     대청주유소   인천 옹진군 대청면 대청로 222  현대오일뱅크    Y  1890  옹진군
# 9     북포주유소   인천 옹진군 백령면 백령로 859  현대오일뱅크    N  1890  옹진군
# 10    장봉주유소   인천 옹진군 북도면 장봉로 467    자가상표    N  1950  옹진군
#
# [316 rows x 6 columns]

# %%
stations_sel.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 316 entries, 0 to 10
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   주유소     316 non-null    object
#  1   주소      316 non-null    object
#  2   상표      316 non-null    object
#  3   셀프여부    316 non-null    object
#  4   가격      316 non-null    int64
#  5   군/구     316 non-null    object
# dtypes: int64(1), object(5)
# memory usage: 17.3+ KB

# %%
stations_sel.reset_index(inplace=True)
stations_sel
# Out:
#      index      주유소                   주소      상표 셀프여부    가격  군/구
# 0        0  하은상사주유소   인천 강화군 길상면 해안동로 75   GS칼텍스    Y  1585  강화군
# 1        1    두운주유소  인천 강화군 불은면 강화동로 508   SK에너지    N  1599  강화군
# 2        2    아름주유소   인천 강화군 선원면 중앙로 150   GS칼텍스    Y  1629  강화군
# 3        3  강화농협주유소    인천 강화군 강화읍 중앙로 70  NH-OIL    Y  1630  강화군
# 4        4    금광주유소    인천 강화군 길상면 까치골길 1   S-OIL    N  1645  강화군
# ..     ...      ...                  ...     ...  ...   ...  ...
# 311      6    연평주유소   인천 옹진군 연평면 연평로 715  현대오일뱅크    N  1890  옹진군
# 312      7    백령주유소   인천 옹진군 백령면 백령로 221   S-OIL    N  1890  옹진군
# 313      8    대청주유소   인천 옹진군 대청면 대청로 222  현대오일뱅크    Y  1890  옹진군
# 314      9    북포주유소   인천 옹진군 백령면 백령로 859  현대오일뱅크    N  1890  옹진군
# 315     10    장봉주유소   인천 옹진군 북도면 장봉로 467    자가상표    N  1950  옹진군
#
# [316 rows x 7 columns]

# %%
del stations_sel['index']
# del stations_sel['level_0']
stations_sel
# Out:
#          주유소                   주소      상표 셀프여부    가격  군/구
# 0    하은상사주유소   인천 강화군 길상면 해안동로 75   GS칼텍스    Y  1585  강화군
# 1      두운주유소  인천 강화군 불은면 강화동로 508   SK에너지    N  1599  강화군
# 2      아름주유소   인천 강화군 선원면 중앙로 150   GS칼텍스    Y  1629  강화군
# 3    강화농협주유소    인천 강화군 강화읍 중앙로 70  NH-OIL    Y  1630  강화군
# 4      금광주유소    인천 강화군 길상면 까치골길 1   S-OIL    N  1645  강화군
# ..       ...                  ...     ...  ...   ...  ...
# 311    연평주유소   인천 옹진군 연평면 연평로 715  현대오일뱅크    N  1890  옹진군
# 312    백령주유소   인천 옹진군 백령면 백령로 221   S-OIL    N  1890  옹진군
# 313    대청주유소   인천 옹진군 대청면 대청로 222  현대오일뱅크    Y  1890  옹진군
# 314    북포주유소   인천 옹진군 백령면 백령로 859  현대오일뱅크    N  1890  옹진군
# 315    장봉주유소   인천 옹진군 북도면 장봉로 467    자가상표    N  1950  옹진군
#
# [316 rows x 6 columns]

# %%
stations_sel_name = stations_sel.set_index('상표')
stations_sel_name
# Out:
#             주유소                   주소 셀프여부    가격  군/구
# 상표
# GS칼텍스   하은상사주유소   인천 강화군 길상면 해안동로 75    Y  1585  강화군
# SK에너지     두운주유소  인천 강화군 불은면 강화동로 508    N  1599  강화군
# GS칼텍스     아름주유소   인천 강화군 선원면 중앙로 150    Y  1629  강화군
# NH-OIL  강화농협주유소    인천 강화군 강화읍 중앙로 70    Y  1630  강화군
# S-OIL     금광주유소    인천 강화군 길상면 까치골길 1    N  1645  강화군
# ...         ...                  ...  ...   ...  ...
# 현대오일뱅크    연평주유소   인천 옹진군 연평면 연평로 715    N  1890  옹진군
# S-OIL     백령주유소   인천 옹진군 백령면 백령로 221    N  1890  옹진군
# 현대오일뱅크    대청주유소   인천 옹진군 대청면 대청로 222    Y  1890  옹진군
# 현대오일뱅크    북포주유소   인천 옹진군 백령면 백령로 859    N  1890  옹진군
# 자가상표      장봉주유소   인천 옹진군 북도면 장봉로 467    N  1950  옹진군
#
# [316 rows x 5 columns]

# %%
import matplotlib.pyplot as plt

plt.rc('font', family='Malgun Gothic')
# plt.rcParams['axex.unicode_minus'] = False
plt.style.use('ggplot')

stations_sel.boxplot(column='가격', by='셀프여부', figsize=(12, 8))
# Out:
# <AxesSubplot:title={'center':'가격'}, xlabel='셀프여부'>

# %%
import seaborn as sns
plt.figure(figsize=(12, 8))
sns.boxplot(
    x='상표', 
    y='가격', 
    hue='셀프여부', # 색상을 셀프여부로 구별함
    data=stations_sel, 
    palette='Set3'
)

plt.show()

# %%
plt.figure(figsize=(12, 8))
sns.boxplot(
    x='군/구',
    y='가격',
    hue='셀프여부',
    data=stations_sel,
    palette='summer'
)
plt.show()
